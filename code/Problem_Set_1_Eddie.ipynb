# %% [markdown]
# <a href="https://colab.research.google.com/github/LinEddie0290/stats201-portfolio-Eddie/blob/main/Problem_Set_1_Eddie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1
#
# Did you get the same data querying via different node operators? Please point to at least one specific observation to validate your answer.
#
# Please insert Figures/Tables to better represent your idea.

# %%
#@title The three tables are the results of querying from three different node operators. As we can see the contents across the tables are the same.
display(df_blocks_alchemy.head())
display(df_blocks.head())
display(df_blocks_QuickNode.head())
# Out:
#      number                                               hash  \
# 0  15537383  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...
# 1  15537384  0xdb8633ed49884077199615b7db53246ea66b53b2ffce...
# 2  15537385  0xe55dd420805e0960c67fca1f9fe8d640c1d017f5ad7f...
# 3  15537386  0x397cd06f166483654bb5c1a16eb40c9beb86417f9fd5...
# 4  15537387  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...
#
#                                          parent_hash               nonce  \
# 0  0x17bcfa915b2bb55d517351e77f89b2fe9c7cc5b65a36...  0x5bcd2bae994d20b4
# 1  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...  0x083bd7336109aee8
# 2  0xdb8633ed49884077199615b7db53246ea66b53b2ffce...  0xd14f22d8d48ef844
# 3  0xe55dd420805e0960c67fca1f9fe8d640c1d017f5ad7f...  0x06ba29b9aaa9278e
# 4  0x397cd06f166483654bb5c1a16eb40c9beb86417f9fd5...  0xeaec918af5cc5509
#
#                                          sha3_uncles  \
# 0  0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a...
# ...

# %% [markdown]
# # Question 2
# Please introduce the ERC20 token that you queried in 100 words:
#
# * when the token first was issued?
#
# * what functions do the token support?
#
# * what is the current market value of the token?
#
#
#
# * Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer. Please insert Figures/Tables to better represent your idea.
#
# ApeCoin was first released on March 16th, 2022 (https://forkast.news/what-is-apecoin-and-how-it-made-the-bored-apes-richer/).
# ApeCoin is mainly used as a governance and utility token within the APE ecosystem,allowing followers to participate in Apecoin DAO as well as granting access to the ecosystem's games, events, and other services(https://bitpay.com/blog/what-is-apecoin/). As of January 26, 2023, ApeCoin is worth $6.15(https://www.coinbase.com/price/apecoin).
#
# The promise of a decentralized internet:
# What is Web3 and how can firms prepare? https://doi.org/10.1016/j.bushor.2022.06.002.
#
# Background/Motivation: Web3 is a next generation internet built upon blockchain technology and applications such as fungible and non fungible tokens. The fast developing web3 can throw business managers off and not know how to utilize this burgeoning internet to further develop their business.
#
# Research Question: How can established companies prepare for a more decentralized internet?
#
# Application Scenario: The author(s) collect studies and information on web1.0, web2.0, web3.0, and web3.0 applications such as NFTs and Metaverse, the studies go back to 2007 to until 2022. Actual information goes from the late 1980s to 2022 since the release of web1.0 in 1989.
#
# Methodology: The authors in this article define four aspects in which the internet evolved in web3.0, and discuss their capacity to increase
# peer-to-peer interactions, decrease large companies’ control of information and
# services, and facilitate access to user networks at a much lower cost than currently
# possible.
#
# Results: Businesses should 1. tokenize intellectual contributions 2. reconsider organizational hierarchy 3. double down on stakeholders and commmunities 4. take caution when investing in web3.0 and 5. reconsider the role of network effects
#
# Intellectual Merits/Practical Impacts: The authors analyzes the effects of the main aspects of web3.0, cryptocurrency, and blockchain technology. They show a path to already established and centralized businesses on how to prepare for the more and more decentralized internet, which would help the development of existing companies like Google and Amazon.

# %% [markdown]
# # Question 3
# Please introduce the ERC721 token that you queried in 100 words:
#
# * when the token first was issued?
# * what functions do the token support?
# * what is the current market value of the token?
# * Find an academic paper or industry report about the token and summary in the 6 facets of background/motivation, research question, application scenario, methodology, results, intellectual merits/practical impacts.
#
# Please provide references that could back-up your answer. Please insert Figures/Tables to better represent your idea.
#
# CryptoKitties was released on November 28th, 2017(https://spectrum.ieee.org/cryptokitties).CryptoKitties is a NFT trading game where players buy, collect, and trade for CryptoKitties cards(https://zipmex.com/learn/cryptokitties-game/).As of January 26th, 2023, the average cost of one CryptoKitties NFT is $20.9(https://www.nft-stats.com/collection/cryptokitties).
#
# CryptoKitties and the
# New Ludic Economy:
# How Blockchain
# Introduces Value,
# Ownership, and Scarcity
# in Digital Gaming DOI: 10.1177/1555412019898305
#
# Background/Motivation: Blockchain technology has been hyped as a "gamechanger in areas like financial services, smart contracts, logistics, secure communication, and governance models." The techonology of Cryptocurrencies also sparked a hype in cryptogaming, such as the popular NFT game CryptoKitties. Thus, Blockchain-based game design and play is something new and worth studying to learn about it's impact to the traditional way of ditribution system of games, boudaries of players and developers, and the importance of user feedback in the gaming infrastructure.
#
# Research Question: Why does Cryptogame Economy not work in terms of the limits of scarcity in value construction for the owners of NFTs.
#
# Application Scenario: The data consists of player-created analytics such as CryptoKitties prices from the first release of CryptoKitties to 2019.
#
# Methodology: The author uses open blockchain analytics such as DappRadar and Etherscan.
#  Combining theoretical cryptocurrency and Bitcoin studies, open data analysis, and virtual ethnography for discussion on blockchain-based game design and play.
#
# Results: The author concludes three major factors that determine the value of cryptogame tokens.
# First, Blockchains are hardly scalable. Operating a crypto wallet requires dedication and skill and is not universally accessible.
# Second, the maintenance of the infrastructure is paid by the users via transfers (“gas”) to cryptocurrency
# miners. In such an unequal economic system, wealthier players can afford to make
# their move first, and players less eager to pay for transaction costs have to endure lag
# and standstill.
# Third, The principle of anonymity and delegation of trust to algorithms and open
# data undermine any possibility of legal protection of full ownership. Therefore,
# account recovery on a blockchain only becomes possible at the price of
# deanonymization.
#
# Intellectual Merits/Practical Impacts: The paper highlights shortcomings of Cryptogaming in terms of economy, which will inspire further research on how to build better economic models for future cryptogames. Factors such as  scalability, maintenance, anonymity, and trustlessness issues should all be considered when designing the crytogame as well as scarcity as the ground principle of cryptogames should be redefined.

# %% [markdown]
# # PART I: Install Required Dependancies

# %%
# import libraries to print data frame
import pandas as pd

# %%
# !python -m pip install ethereum-etl pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.0/336.0 KB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.8/501.8 KB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 KB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 KB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 KB 8.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # PART II: Mount Google Drive for Result Exports

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# print the current directory
# !pwd
# Out:
# /content

# %%
#@title path
#create a project folder and identify the path
path = "/content" #@param {type:"string"}

# %%
#go to your project folder 
# %cd /content
# Out:
# /content

# %%
# print the current directory again to make sure that you are in the project folder
# !pwd
# Out:
# /content

# %% [markdown]
# # PART III: Query Data and Export CSV

# %%
#@title import using Alchemy
alchemy_url = "https://eth-mainnet.g.alchemy.com/v2/API_KEY" #@param {type:"string"}

# %%
#@title the merge
merge = 15537393 #@param {type:"number"}

# %%
#@title data radius
radius = 10 #@param {type:"number"}

# %%
### find the start and the end
start = merge-radius
end = merge+radius
print(start, end)
# Out:
# 15537383 15537403

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537383 --end-block 15537403 --blocks-output blocks_alchemy.csv --provider-uri https://eth-mainnet.g.alchemy.com/v2/API_KEY
# Out:
# 2023-01-26 08:27:40,654 - ProgressLogger [INFO] - Started work. Items to process: 21.
# 2023-01-26 08:27:40,905 - ProgressLogger [INFO] - 21 items processed. Progress is 100%.
# 2023-01-26 08:27:40,905 - ProgressLogger [INFO] - Finished work. Total items processed: 21. Took 0:00:00.251155.
# 2023-01-26 08:27:40,905 - CompositeItemExporter [INFO] - block items exported: 21
# 2023-01-26 08:27:40,905 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_alchemy = pd.read_csv('./blocks_alchemy.csv')
display(df_blocks_alchemy.head(10))
# Out:
#      number                                               hash  \
# 0  15537383  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...
# 1  15537384  0xdb8633ed49884077199615b7db53246ea66b53b2ffce...
# 2  15537385  0xe55dd420805e0960c67fca1f9fe8d640c1d017f5ad7f...
# 3  15537386  0x397cd06f166483654bb5c1a16eb40c9beb86417f9fd5...
# 4  15537387  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...
# 5  15537388  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...
# 6  15537389  0xc81d887fda0e021a4c54e68f9b6a78d3b70deb18b8af...
# 7  15537390  0xd5b9efdd3659f5b635e0505d787d6b6cc3af4c660def...
# 8  15537391  0x2f1dc309c7cc0a5a2e3b3dd9315fea0ffbc53c56f923...
# 9  15537392  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...
#
#                                          parent_hash               nonce  \
# 0  0x17bcfa915b2bb55d517351e77f89b2fe9c7cc5b65a36...  0x5bcd2bae994d20b4
# 1  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...  0x083bd7336109aee8
# ...

# %%
#@title Import using the Infura node
infura_end_points_URL = "https://mainnet.infura.io/v3/API_KEY" #@param {type:"string"}

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537383 --end-block 15537403 --blocks-output blocks.csv --provider-uri https://mainnet.infura.io/v3/API_KEY
# Out:
# 2023-01-26 08:28:40,538 - ProgressLogger [INFO] - Started work. Items to process: 21.
# 2023-01-26 08:28:41,122 - ProgressLogger [INFO] - 21 items processed. Progress is 100%.
# 2023-01-26 08:28:41,122 - ProgressLogger [INFO] - Finished work. Total items processed: 21. Took 0:00:00.583679.
# 2023-01-26 08:28:41,122 - CompositeItemExporter [INFO] - block items exported: 21
# 2023-01-26 08:28:41,122 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
# set to print the maximum numbers of rows
pd.set_option('display.max_rows', None)

# %%
df_blocks = pd.read_csv('./blocks.csv')
display(df_blocks.head(10))
# Out:
#      number                                               hash  \
# 0  15537383  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...
# 1  15537384  0xdb8633ed49884077199615b7db53246ea66b53b2ffce...
# 2  15537385  0xe55dd420805e0960c67fca1f9fe8d640c1d017f5ad7f...
# 3  15537386  0x397cd06f166483654bb5c1a16eb40c9beb86417f9fd5...
# 4  15537387  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...
# 5  15537388  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...
# 6  15537389  0xc81d887fda0e021a4c54e68f9b6a78d3b70deb18b8af...
# 7  15537390  0xd5b9efdd3659f5b635e0505d787d6b6cc3af4c660def...
# 8  15537391  0x2f1dc309c7cc0a5a2e3b3dd9315fea0ffbc53c56f923...
# 9  15537392  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...
#
#                                          parent_hash               nonce  \
# 0  0x17bcfa915b2bb55d517351e77f89b2fe9c7cc5b65a36...  0x5bcd2bae994d20b4
# 1  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...  0x083bd7336109aee8
# ...

# %%
#@title Query Transaction Data using Infura
# !ethereumetl export_blocks_and_transactions --start-block 15537383 --end-block 15537403 --transactions-output transactions.csv --provider-uri https://mainnet.infura.io/v3/API_KEY
# Out:
# 2023-01-26 08:28:45,828 - ProgressLogger [INFO] - Started work. Items to process: 21.
# 2023-01-26 08:28:47,336 - ProgressLogger [INFO] - 21 items processed. Progress is 100%.
# 2023-01-26 08:28:47,337 - ProgressLogger [INFO] - Finished work. Total items processed: 21. Took 0:00:01.508347.
# 2023-01-26 08:28:47,337 - CompositeItemExporter [INFO] - block items exported: 0
# 2023-01-26 08:28:47,337 - CompositeItemExporter [INFO] - transaction items exported: 2305

# %%
df_transactions = pd.read_csv('./transactions.csv')
display(df_transactions.head())
# Out:
#                                                 hash  nonce  \
# 0  0x4fcad43d7863150e73422a9c357c4bc02fe24bc51ee9...   5431
# 1  0x471b26e3a6547a04a7d6aa9ea576f7adce87054398cd...  91812
# 2  0x3a7228edefcf2f708c8c02840db0d4da3bab4065acfa...   1168
# 3  0xd072536c3e791ac0f8ae62943f9f16392a67168c7dc0...     46
# 4  0x4c08d93d973e406fe72b144bb1977976abd417490571...    258
#
#                                           block_hash  block_number  \
# 0  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...      15537383
# 1  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...      15537383
# 2  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...      15537383
# 3  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...      15537383
# 4  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...      15537383
#
#    transaction_index                                from_address  \
# 0                  0  0x479bc00624e58398f4cf59d78884d12fb515790a
# 1                  1  0x005fde5294199d5c3eb5eb7a6e51954123b74b1c
# ...

# %%
#@title Query all Token Transfers using QuickNode
# !ethereumetl export_token_transfers --start-block 15537383 --end-block 15537403 --provider-uri https://intensive-magical-fire.discover.quiknode.pro/API_KEY --output token_transfers.csv
# Out:
# 2023-01-26 08:28:48,348 - ProgressLogger [INFO] - Started work. Items to process: 21.
# 2023-01-26 08:28:57,596 - ProgressLogger [INFO] - 21 items processed. Progress is 100%.
# 2023-01-26 08:28:57,596 - ProgressLogger [INFO] - Finished work. Total items processed: 21. Took 0:00:09.248409.
# 2023-01-26 08:28:57,596 - CompositeItemExporter [INFO] - token_transfer items exported: 31772

# %%
df_token_transfers = pd.read_csv('./token_transfers.csv')
display(df_token_transfers.head())
# Out:
#                                 token_address  \
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                  from_address  \
# 0  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 1  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94
# 2  0x4a137fd5e7a256ef08a7de531a17d0be0cc7b6b6
# 3  0x088ee5007c98a9677165d78dd2109ae4a3d04d0c
# 4  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
#
#                                    to_address                 value  \
# 0  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94           32735264456
# 1  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  20498755359241656671
# 2  0x088ee5007c98a9677165d78dd2109ae4a3d04d0c    751404088482250960
# 3  0x4a137fd5e7a256ef08a7de531a17d0be0cc7b6b6   4153428815413696263
# ...

# %%
df = df_token_transfers[df_token_transfers.token_address=="0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"]
df.head()
# Out:
#                                  token_address  \
# 1   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 5   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 8   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 12  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                   from_address  \
# 1   0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94
# 3   0x088ee5007c98a9677165d78dd2109ae4a3d04d0c
# 5   0x1111111254fb6c44bac0bed2854e76f90643097d
# 8   0xdef1c0ded9bec7f1a1670819833240f027b25eff
# 12  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
#
#                                     to_address                 value  \
# 1   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  20498755359241656671
# 3   0x4a137fd5e7a256ef08a7de531a17d0be0cc7b6b6   4153428815413696263
# 5   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  30900000000000000000
# 8   0x130f4322e5838463ee460d5854f5d472cfc8f253    218075000000000000
# ...

# %%
#@title import using QuickNode
QuickNode_end_points_URL = "https://intensive-magical-fire.discover.quiknode.pro/API_KEY" #@param {type:"string"}

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15537383 --end-block 15537403 --blocks-output blocks_QuickNode.csv --provider-uri https://intensive-magical-fire.discover.quiknode.pro/42eb3609e2269ac046c856f35088a2ad9ae60025/
# Out:
# 2023-01-26 08:28:59,128 - ProgressLogger [INFO] - Started work. Items to process: 21.
# 2023-01-26 08:28:59,241 - ProgressLogger [INFO] - 21 items processed. Progress is 100%.
# 2023-01-26 08:28:59,241 - ProgressLogger [INFO] - Finished work. Total items processed: 21. Took 0:00:00.113365.
# 2023-01-26 08:28:59,241 - CompositeItemExporter [INFO] - block items exported: 21
# 2023-01-26 08:28:59,241 - CompositeItemExporter [INFO] - transaction items exported: 0

# %%
df_blocks_QuickNode = pd.read_csv('./blocks_QuickNode.csv')
display(df_blocks_QuickNode.head(10))
# Out:
#      number                                               hash  \
# 0  15537383  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...
# 1  15537384  0xdb8633ed49884077199615b7db53246ea66b53b2ffce...
# 2  15537385  0xe55dd420805e0960c67fca1f9fe8d640c1d017f5ad7f...
# 3  15537386  0x397cd06f166483654bb5c1a16eb40c9beb86417f9fd5...
# 4  15537387  0x5a2504b5e378f28d8f1fc52bac609eca4f3d79f444c5...
# 5  15537388  0x34f2900754317c14b2479f9a0342b0f4e16bd4681a5f...
# 6  15537389  0xc81d887fda0e021a4c54e68f9b6a78d3b70deb18b8af...
# 7  15537390  0xd5b9efdd3659f5b635e0505d787d6b6cc3af4c660def...
# 8  15537391  0x2f1dc309c7cc0a5a2e3b3dd9315fea0ffbc53c56f923...
# 9  15537392  0x2b3ea3cd4befcab070812443affb08bf17a91ce382c7...
#
#                                          parent_hash               nonce  \
# 0  0x17bcfa915b2bb55d517351e77f89b2fe9c7cc5b65a36...  0x5bcd2bae994d20b4
# 1  0x1eeea30a960dd0a5702f751f1722b41f4e9730c20262...  0x083bd7336109aee8
# ...

# %% [markdown]
# **Query ECR20 Token**

# %%
#@title Token Name
Token_Name = "ApeCoin" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "APE" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0x4d224452801ACEd8B2F0aebE155379bb5D594381" #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 15537383 --end-block 15537403 --provider-uri https://mainnet.infura.io/v3/API_KEY --output token_transfers_APE.csv --tokens 0x4d224452801ACEd8B2F0aebE155379bb5D594381
# Out:
# 2023-01-26 08:29:00,441 - ProgressLogger [INFO] - Started work. Items to process: 21.
# 2023-01-26 08:29:00,885 - ProgressLogger [INFO] - 21 items processed. Progress is 100%.
# 2023-01-26 08:29:00,885 - ProgressLogger [INFO] - Finished work. Total items processed: 21. Took 0:00:00.444170.
# 2023-01-26 08:29:00,886 - CompositeItemExporter [INFO] - token_transfer items exported: 3

# %%
df_token_transfers_APE = pd.read_csv('./token_transfers_APE.csv')
display(df_token_transfers_APE.head())
# Out:
#                                 token_address  \
# 0  0x4d224452801aced8b2f0aebe155379bb5d594381
# 1  0x4d224452801aced8b2f0aebe155379bb5d594381
# 2  0x4d224452801aced8b2f0aebe155379bb5d594381
#
#                                  from_address  \
# 0  0x130f4322e5838463ee460d5854f5d472cfc8f253
# 1  0x74de5d4fcbf63e00296fd95d33236b9794016631
# 2  0xac4b3dacb91461209ae9d41ec517c2b9cb1b7daf
#
#                                    to_address                   value  \
# 0  0x74de5d4fcbf63e00296fd95d33236b9794016631    67276683190449227606
# 1  0x094739479e2685dc6f03aad39bdf29f56d033ff2    67276683190449227606
# 2  0x57c1e0c2adf6eecdb135bcf9ec5f23b319be2c94  5851409883528072114782
#
#                                     transaction_hash  log_index  block_number
# 0  0x4c08d93d973e406fe72b144bb1977976abd417490571...         18      15537383
# 1  0x4c08d93d973e406fe72b144bb1977976abd417490571...         21      15537383
# ...

# %% [markdown]
# Query ERC721 Token

# %%
#@title Token Name
Token_Name = "CryptoKitties" #@param {type:"string"}

# %%
#@title Token Symbol
Token_Symbol = "CK" #@param {type:"string"}

# %%
#@title Token Address
token_address = "0x06012c8cf97BEaD5deAe237070F9587f8E7A266d" #@param {type:"string"}

# %%
# !ethereumetl export_token_transfers --start-block 15537293 --end-block 15537493 --provider-uri https://mainnet.infura.io/v3/API_KEY --output token_transfers_CK.csv --tokens 0x06012c8cf97BEaD5deAe237070F9587f8E7A266d
# Out:
# 2023-01-26 08:29:03,533 - ProgressLogger [INFO] - Started work. Items to process: 201.
# 2023-01-26 08:29:04,476 - ProgressLogger [INFO] - 101 items processed. Progress is 50%.
# 2023-01-26 08:29:04,516 - ProgressLogger [INFO] - 201 items processed. Progress is 100%.
# 2023-01-26 08:29:04,517 - ProgressLogger [INFO] - Finished work. Total items processed: 201. Took 0:00:00.983534.
# 2023-01-26 08:29:04,517 - CompositeItemExporter [INFO] - token_transfer items exported: 6

# %%
df_token_transfers_CK = pd.read_csv('./token_transfers_CK.csv')
display(df_token_transfers_CK.head(6))
# Out:
#                                 token_address  \
# 0  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 1  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 2  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 3  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 4  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 5  0x06012c8cf97bead5deae237070f9587f8e7a266d
#
#                                  from_address  \
# 0  0x4d217de4213e98e31dd3aacb4a95199045c15065
# 1  0x4d217de4213e98e31dd3aacb4a95199045c15065
# 2  0x4d217de4213e98e31dd3aacb4a95199045c15065
# 3  0x4d217de4213e98e31dd3aacb4a95199045c15065
# 4  0x4d217de4213e98e31dd3aacb4a95199045c15065
# 5  0x4d217de4213e98e31dd3aacb4a95199045c15065
#
#                                    to_address    value  \
# 0  0xb1690c08e213a35ed9bab7b318de14420fb57d8c  1337554
# 1  0xb1690c08e213a35ed9bab7b318de14420fb57d8c  1340208
# 2  0xb1690c08e213a35ed9bab7b318de14420fb57d8c  1447464
# 3  0xb1690c08e213a35ed9bab7b318de14420fb57d8c  1459873
# ...
